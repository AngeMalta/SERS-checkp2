# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeMalta/SERS-checkp2/blob/main/CP2_SERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# preparando ambiente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# algoritmo classification ---> regressão logistica ---> entrega possibility classes
# 0: stable --- 1: unstable
# registro A -> [0.98, 0.02] ---> 0
# registro B -> [0.64, 0.36] ---> 0
# registro C -> [0.49, 0.51] ---> 1
from sklearn.linear_model import LogisticRegression
# Separação dos dados para treinamento e para teste (train-test-split)
from sklearn.model_selection import train_test_split

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/AngeMalta/SERS-checkp2/refs/heads/main/Data_for_UCI_named.csv')
dados.head()

# %%
# Features
X = dados.drop(columns = ['stab', 'stabf'], axis=1)
X.head()
